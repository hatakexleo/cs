# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("main.csv")

# %%
df
# Out:
#        crop  Estimated_Insects_Count  Soil_Type  Pesticide_Use_Category  \
# 0         0                      731          0                       1
# 1         0                      731          0                       1
# 2         0                      731          0                       1
# 3         0                      731          0                       1
# 4         0                      731          0                       1
# ...     ...                      ...        ...                     ...
# 19995     1                      677          1                       3
# 19996     1                      677          1                       3
# 19997     1                      677          1                       3
# 19998     1                      677          1                       3
# 19999     1                      677          1                       3
#
#        Number_Doses_Week  Number_Weeks_Used  Number_Weeks_Quit  Season    N  \
# ...

# %%
df.shape
# Out:
# (20000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   crop                     20000 non-null  int64
#  1   Estimated_Insects_Count  20000 non-null  int64
#  2   Soil_Type                20000 non-null  int64
#  3   Pesticide_Use_Category   20000 non-null  int64
#  4   Number_Doses_Week        20000 non-null  int64
#  5   Number_Weeks_Used        20000 non-null  int64
#  6   Number_Weeks_Quit        20000 non-null  int64
#  7   Season                   20000 non-null  int64
#  8   N                        20000 non-null  int64
#  9   P                        20000 non-null  int64
#  10  K                        20000 non-null  int64
#  11  temperature              20000 non-null  float64
#  12  humidity                 20000 non-null  float64
#  13  ph                       20000 non-null  float64
# ...

# %%
df.drop(['label'],axis=1,inplace=True)

# %%
l=[]
for _ in range(len(df)):
    l.append(np.random.randint(80, 100))

# %%
df['Crop_Damage']=l

# %%
df
# Out:
#        crop  Estimated_Insects_Count  Soil_Type  Pesticide_Use_Category  \
# 0         0                      731          0                       1
# 1         0                      731          0                       1
# 2         0                      731          0                       1
# 3         0                      731          0                       1
# 4         0                      731          0                       1
# ...     ...                      ...        ...                     ...
# 19995     1                      677          1                       3
# 19996     1                      677          1                       3
# 19997     1                      677          1                       3
# 19998     1                      677          1                       3
# 19999     1                      677          1                       3
#
#        Number_Doses_Week  Number_Weeks_Used  Number_Weeks_Quit  Season    N  \
# ...

# %%
main_df=pd.DataFrame(columns=[x for x in df.columns])

# %%
main_df
# Out:
# Empty DataFrame
# Columns: [crop, Estimated_Insects_Count, Soil_Type, Pesticide_Use_Category, Number_Doses_Week, Number_Weeks_Used, Number_Weeks_Quit, Season, N, P, K, temperature, humidity, ph, rainfall, Crop_Damage]
# Index: []

# %%
l=[]
for _ in range(len(df)):
    l.append(np.random.randint(0, 2))

# %%
main_df.crop=l

# %%
def create(k):
    l=[]
    a=min(k)
    b=max(k) if max(k)>0 else 1
    print(a,b)
    for _ in range(len(df)):
#         l.append(np.random.randint(int(min(k)*2//3), int(max(k)*2//3)))
        l.append(np.random.randint(a,b+1))

    return l

# %%
for i in df:
    l=create(df[i])
    main_df[i]=l
# Out:
# 0 1
# 150 4096
# 0 1
# 1 3
# 0 80
# 0 44
# 0 1
# 1 3
# 60 140
# 35 60
# 15 45
# 20.0454142 26.92995077
# 75.00539324 84.96907151
# 5.005306977 7.994679507
# 60.65381719 298.5601175
# 80 99

# %%
main_df
# Out:
#        crop  Estimated_Insects_Count  Soil_Type  Pesticide_Use_Category  \
# 0         0                      604          1                       1
# 1         0                      444          0                       1
# 2         1                     2595          0                       1
# 3         1                      523          1                       1
# 4         0                     2854          1                       1
# ...     ...                      ...        ...                     ...
# 19995     0                     3124          0                       3
# 19996     1                     2621          0                       1
# 19997     0                     3714          0                       3
# 19998     1                     3314          0                       3
# 19999     1                     1551          0                       1
#
#        Number_Doses_Week  Number_Weeks_Used  Number_Weeks_Quit  Season    N  \
# ...

# %%
main_df=main_df.drop(['Estimated_Insects_Count','Number_Doses_Week','Number_Weeks_Used','Number_Weeks_Quit','N','P','K','temperature','humidity','ph'],axis=1)

# %%
df=main_df

# %%
df.apply(lambda x:create(x))
# Out:
# 0 1
# 0 1
# 1 3
# 1 3
# 60 298
# 80 99
#        crop  Soil_Type  Pesticide_Use_Category  Season  rainfall  Crop_Damage
# 0         0          1                       2       3       194           97
# 1         0          1                       1       3       271           94
# 2         0          0                       1       2       255           91
# 3         0          1                       1       2       199           91
# 4         0          0                       1       1       254           95
# ...     ...        ...                     ...     ...       ...          ...
# 19995     0          0                       1       2       210           90
# 19996     1          1                       2       3       113           87
# 19997     1          1                       1       2       277           99
# 19998     0          0                       2       1       193           83
# ...

# %%
num_samples=20000
l=np.random.choice(['Amidosulfuron','Lamba-Cyhalothrin','Chlormequat'], size=num_samples)
df['Pesticide_Use_Category']=l
df.to_csv('small.csv')

# %%
# num_samples=10000
# data = {
#     'Crop': np.random.choice([0, 1], size=num_samples),
#     'Soil_Type': np.random.choice([0, 1], size=num_samples),
#     'Pesticide_Use_Category': np.random.choice([1,2,3], size=num_samples),
#     'Season': np.random.choice([1, 2, 3], size=num_samples),
#     'Rainfall': np.random.randint(50, 300, size=num_samples),
#     'Crop_Damage': np.random.randint(70, 99, size=num_samples)
# }

# Create DataFrame
df = pd.read_csv('small.csv')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
# l=[]
# for i in df['Pesticide_Use_Category']:
#         l.append(chr(ord('a')+i-1))

# %%
# df['Pesticide_Use_Category']=l
# df

# %%
df1=pd.get_dummies(df['Pesticide_Use_Category'])
df1
# Out:
#        Amidosulfuron  Chlormequat  Lamba-Cyhalothrin
# 0                  0            0                  1
# 1                  0            1                  0
# 2                  0            0                  1
# 3                  0            1                  0
# 4                  0            0                  1
# ...              ...          ...                ...
# 19995              0            0                  1
# 19996              0            0                  1
# 19997              0            1                  0
# 19998              0            0                  1
# 19999              0            1                  0
#
# [20000 rows x 3 columns]

# %%
df=pd.concat([df,df1],axis=1)

# %%
df
# Out:
#        crop  Soil_Type Pesticide_Use_Category  Season  rainfall  Crop_Damage  \
# 0         0          1      Lamba-Cyhalothrin       2       144           86
# 1         0          0            Chlormequat       3       112           93
# 2         1          0      Lamba-Cyhalothrin       3       283           88
# 3         1          1            Chlormequat       1        65           91
# 4         0          1      Lamba-Cyhalothrin       3       252           90
# ...     ...        ...                    ...     ...       ...          ...
# 19995     0          0      Lamba-Cyhalothrin       2       202           97
# 19996     1          0      Lamba-Cyhalothrin       2       199           83
# 19997     0          0            Chlormequat       1       142           97
# 19998     1          0      Lamba-Cyhalothrin       2       284           87
# 19999     1          0            Chlormequat       2       187           92
#
# ...

# %%
df.drop(['Pesticide_Use_Category'],axis=1,inplace=True)

# %%
# from sklearn.preprocessing import StandardScaler
# scaler=StandardScaler()

# %%
# from sklearn.preprocessing import StandardScaler

# # Assuming df is your DataFrame
# scaler = StandardScaler()

# for i in df.columns:
#     # Fit the scaler on the column
#     scaler.fit(df[[i]])
    
#     # Transform the column and assign it back to the DataFrame
#     df[[i]] = scaler.transform(df[[i]])

# %%
x_in=df.drop(['Crop_Damage'],axis=1)
y_in=df[['Crop_Damage']]

# %%
from sklearn.model_selection import train_test_split
X,x,Y,y=train_test_split(x_in,y_in,test_size=0.2)

# %%
df.head(5)
# Out:
#    crop  Soil_Type  Season  rainfall  Crop_Damage  Amidosulfuron  Chlormequat  \
# 0     0          1       2       144           86              0            0
# 1     0          0       3       112           93              0            1
# 2     1          0       3       283           88              0            0
# 3     1          1       1        65           91              0            1
# 4     0          1       3       252           90              0            0
#
#    Lamba-Cyhalothrin
# 0                  1
# 1                  0
# 2                  1
# 3                  0
# 4                  1

# %%
from sklearn.linear_model import LinearRegression
LinReg=LinearRegression()
LinReg.fit(X,Y)
# Out:
# LinearRegression()

# %%
LinReg.predict([[1,0,2,111,0,0,1]])
# Out:
# /home/kali/.local/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[89.47756215]])

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)

cross_val_score(LinearRegression(),x_in,y_in,cv=cv)
# Out:
# array([ 3.75591678e-05,  3.19352278e-04, -1.22973021e-04, -6.45665688e-04,
#        -1.09860824e-04])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridsearchcv(x,y):
    algos={
        'linear_regression':{
            'model': LinearRegression(),
            'params':{
#                 'normalize':[True,False]
            }
        },
        'lasso':
        {
            'model': Lasso(),
            'params':{
                'alpha':[1,2],
                'selection':['random','cyclic']
            }
        },
        'decision_tree':
        {
            'model':DecisionTreeRegressor(),
            'params':{
                'criterion':['squared_error','friedman_mse'],
                'splitter':['best','random']
            }
        }
    }
    
    scores=[]
    cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algo_name,config in algos.items():
        gs=GridSearchCV(config['model'],config['params'],cv=cv,return_train_score=False)
        gs.fit(x,y)
        scores.append({
            'model':algo_name,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

# %%
# find_best_model_using_gridsearchcv(x_in,y_in)

# %%
df
# Out:
#        crop  Soil_Type  Season  rainfall  Crop_Damage  Amidosulfuron  \
# 0         0          1       2       144           86              0
# 1         0          0       3       112           93              0
# 2         1          0       3       283           88              0
# 3         1          1       1        65           91              0
# 4         0          1       3       252           90              0
# ...     ...        ...     ...       ...          ...            ...
# 19995     0          0       2       202           97              0
# 19996     1          0       2       199           83              0
# 19997     0          0       1       142           97              0
# 19998     1          0       2       284           87              0
# 19999     1          0       2       187           92              0
#
#        Chlormequat  Lamba-Cyhalothrin
# 0                0                  1
# 1                1                  0
# ...

# %%
import pickle
with open('crop_score.pickle','wb') as f:
    pickle.dump(LinReg,f)

# %%
import json
columns={
    'data_columns' : [col.lower() for col in x_in.columns]
}

with open('columns.json','w') as f:
    f.write(json.dumps(columns))

# %%
df.columns
# Out:
# Index(['crop', 'Soil_Type', 'Season', 'rainfall', 'Crop_Damage',
#        'Amidosulfuron', 'Chlormequat', 'Lamba-Cyhalothrin'],
#       dtype='object')
